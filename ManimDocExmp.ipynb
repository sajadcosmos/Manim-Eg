# %%
from manim import *
from colour import Color

# %%
# %%manim -ql -v WARNING ManimCELogo
#
# class ManimCELogo(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         logo_green = "#87c2a5"
#         logo_blue = "#525893"
#         logo_red = "#e07a5f"
#         logo_black = "#343434"
#         ds_m = MathTex(r"\mathbb{M}", fill_color=logo_black).scale(7)
#         ds_m.shift(2.25 * LEFT + 1.5 * UP)
#         circle = Circle(color=logo_green, fill_opacity=1).shift(LEFT)
#         square = Square(color=logo_blue, fill_opacity=1).shift(UP)
#         triangle = Triangle(color=logo_red, fill_opacity=1).shift(RIGHT)
#         logo = VGroup(triangle, square, circle, ds_m)  # order matters
#         logo.move_to(ORIGIN)
#         self.add(logo)

# %%
# %%manim -ql -v WARNING ManimCELogo
# from manim import *
#
# class ManimCELogo(Scene):
#     def construct(self):
#         numplane=NumberPlane()
#         axis=Axes(x_range=[-20,20],y_range=[-20,20],x_length=8,y_length=8).set_color(RED)
#         self.camera.background_color = "#ece6e2"
#         logo_green = "#87c2a5"
#         logo_blue = "#525893"
#         logo_red = "#e07a5f"
#         logo_black = "#343434"
#         ds_m = MathTex(r"\mathbb{M}", fill_color=logo_black)#.scale(7)
#         #ds_m.shift(2.25 * LEFT + 1.5 * UP)
#         circle = Circle(color=logo_green, fill_opacity=1)#.shift(LEFT)
#         square = Square(color=logo_blue, fill_opacity=1)#.shift(UP)
#         triangle = Triangle(color=logo_red, fill_opacity=1)#.shift(RIGHT)
#         logo = VGroup(triangle, square, circle, ds_m)  # order matters
#         #logo.move_to(ORIGIN)
#         self.add(logo,axis,numplane)
#         #self.play(Rotate(ds_m,about_point=([-2.25,1.5,0]),angle=2*PI),rate_func=linear,run_time=3)

# %%
# %%manim -ql -v WARNING UsingRotate
# from manim import *
#
# class UsingRotate(Scene):
#     def construct(self):
#         self.play(
#             Rotate(
#                 Square(side_length=0.5).shift(LEFT * 2),
#                 angle=-2*PI,
#                 about_point=ORIGIN,
#                 rate_func=linear,
#             ),
#             Rotate(Square(side_length=0.5), angle=2*PI, rate_func=linear),
#
#             )
# Out:
# <video src="media\jupyter\UsingRotate@2022-07-24@11-53-54.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -ql -v WARNING vGSq
# class vGSq(Scene):
#
#     def construct (self):
#         x=VGroup()
#         for i in range(10):
#             sq=Square().scale(0.2)
#             x.add(sq)
#         x.set_x(0).arrange(buff=.3)
#         self.add(x)
#         #self.play(Rotate(x,about_point=ORIGIN))
#         for i in range(10):
#             self.play(
#             Rotate(x[i],
#                 angle=-2*PI*(-1)**i,
#                 about_point=ORIGIN,
#                 rate_func=linear,
#             ),
#
#
#             )
#             #self.play(FadeOut(x[i]))
# Out:
# <video src="media\jupyter\vGSq@2022-07-24@12-27-28.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -ql -v WARNING SquareRota
# class SquareRota(Scene):
#     def construct(self):
#
#         sqr=VGroup(*[Square(color=Color(hue=j/20, saturation=1, luminance=0.5), fill_opacity=0.8) for j in range(5)])
#         sqr.arrange(RIGHT).scale(0.5)
#         self.play(DrawBorderThenFill(sqr), run_time=2)
#         self.play(
#             Rotate(sqr[0], PI, rate_func=lambda t: t), # rate_func=linear
#             Rotate(sqr[1], -PI, rate_func=lambda t: t),  # default behavior for most animations
#             Rotate(sqr[2], PI, rate_func=lambda t: t),
#             Rotate(sqr[3], -PI, rate_func=lambda t: t),
#             Rotate(sqr[4], PI, rate_func=lambda t: t),
#             run_time=2
#         )
#         self.wait()
# Out:
# <video src="media\jupyter\SquareRota@2022-07-24@18-03-50.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -ql -v WARNING fun
# class fun(Scene):
#     def construct(self):
#         sqr=VGroup(*[Square(color=Color(hue=j/20, saturation=1, luminance=0.5), fill_opacity=0.8) for j in range(5)])
#         sqr.arrange(RIGHT).scale(0.5)
#         self.play(DrawBorderThenFill(sqr), run_time=2)
#
#
#         def f(n):
#             str='self.play('
#             for i in range(n):
#                 if i<n-1:
#                     #c=i
#                     m=str(i)
#                     str=str+'Rotate(sqr['+m+'],'
#
#                 else:
#                     str=str+')'
#         return str
#         f(5)
# Out:
# <video src="media\jupyter\fun@2022-07-24@18-43-17.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -ql -v WARNING SquareRotaa
# class SquareRotaa(Scene):
#     def construct(self):
#         sqr=VGroup(*[Square(color=Color(hue=j/20, saturation=1, luminance=0.5), fill_opacity=0.8) for j in range(5)])
#         sqr.arrange(RIGHT).scale(0.5)
#         self.play(DrawBorderThenFill(sqr), run_time=2)
#         self.play(AnimationGroup(*[Rotate(s for s in sqr)], lag_ratio=0))
#         self.wait(2)

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING

# %%
# %%manim -ql -v WARNING
